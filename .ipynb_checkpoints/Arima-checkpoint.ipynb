# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pylab as plt
# %matplotlib inline
from statsmodels.tsa.arima_model import ARIMA

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
btc= pd.read_csv('bitcoin_price.csv', parse_dates=['Date'])
eth = pd.read_csv('ethereum_price.csv', parse_dates=['Date'])
bch = pd.read_csv('bitcoin_cash_price.csv', parse_dates=['Date'])
#bitconn=pd.read_csv('bitconnect_price.csv')
dash=pd.read_csv('dash_price.csv', parse_dates=['Date'])
ethcls=pd.read_csv('ethereum_classic_price.csv', parse_dates=['Date'])
iota = pd.read_csv('iota_price.csv', parse_dates=['Date'])
litecoin = pd.read_csv('litecoin_price.csv', parse_dates=['Date'])
monero = pd.read_csv('monero_price.csv', parse_dates=['Date'])
nem = pd.read_csv('nem_price.csv', parse_dates=['Date'])
neo = pd.read_csv('neo_price.csv', parse_dates=['Date'])
numeraire = pd.read_csv('numeraire_price.csv', parse_dates=['Date'])
ripple = pd.read_csv('ripple_price.csv', parse_dates=['Date'])
stratis = pd.read_csv('stratis_price.csv', parse_dates=['Date'])
waves = pd.read_csv('waves_price.csv', parse_dates=['Date'])

# %%
dash.iloc[::-1].head()
# Out:
#         Date    Open    High     Low   Close      Volume     Market Cap
# 0 2017-11-07  274.87  304.55  274.87  293.38  92,431,200  2,109,120,000
# 1 2017-11-06  273.47  280.44  268.46  275.68  60,053,700  2,097,820,000
# 2 2017-11-05  274.33  277.00  270.29  273.17  41,028,900  2,103,900,000
# 3 2017-11-04  278.58  280.96  271.31  274.68  49,462,600  2,135,920,000
# 4 2017-11-03  263.89  281.39  262.98  278.59  62,984,900  2,021,200,000

# %%
btc = btc.iloc[::-1]
eth = eth.iloc[::-1]
bch = bch.iloc[::-1]
dash= dash.iloc[::-1]
ethcls= ethcls.iloc[::-1]
iota = iota.iloc[::-1]
litecoin = litecoin.iloc[::-1]
monero = monero.iloc[::-1]
nem = nem.iloc[::-1]
neo = neo.iloc[::-1]
numeraire = numeraire.iloc[::-1]
ripple = ripple.iloc[::-1]
stratis = stratis.iloc[::-1]
waves = waves.iloc[::-1]

# %%
df_crypto = pd.DataFrame(bch)

df_crypto = df_crypto[['Date','Close']]
df_crypto.set_index('Date', inplace = True)

df_crypto = df_crypto['Close']
df_crypto.head()
# Out:
# Date
# 2017-07-23    413.06
# 2017-07-24    440.70
# 2017-07-25    406.90
# 2017-07-26    365.82
# 2017-07-27    385.48
# Name: Close, dtype: float64

# %%
plt.plot(df_crypto)
plt.ylabel("Value in USD")
plt.xlabel("DATE")
plt.show()

# %%
# fit model
model = ARIMA(df_crypto, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                  107
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -563.088
# Method:                       css-mle   S.D. of innovations             46.638
# Date:                Thu, 07 Dec 2017   AIC                           1140.175
# Time:                        13:42:29   BIC                           1158.885
# Sample:                    07-24-2017   HQIC                          1147.760
#                          - 11-07-2017
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             2.0830      4.481      0.465      0.643      -6.700      10.866
# ar.L1.D.Close     0.2527      0.097      2.616      0.010       0.063       0.442
# ar.L2.D.Close    -0.2359      0.099     -2.379      0.019      -0.430      -0.042
# ...

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
X = df_crypto.values
size = int(len(X) * 0.80)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = np.zeros(len(test))
print(len(test))
average=0
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions[t]=yhat
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
    average=average+((math.fabs(yhat-obs))/obs)
   # print('average',average)
error = mean_squared_error(test, predictions)
avg=(average/len(test))*100
print('Test',avg)
#print('predicted',predictions)
r2 =r2_score(test,predictions)

print('Test MSE: %.3f' % error)
print('r2 score:',r2)
# plot
#print(error)
# Out:
# 22
# predicted=314.203514, expected=371.730000
# predicted=386.487052, expected=339.170000
# predicted=314.999414, expected=330.810000
# predicted=330.295914, expected=327.440000
# predicted=332.864836, expected=323.360000
# predicted=323.018949, expected=331.660000
# predicted=333.688379, expected=315.600000
# predicted=309.012404, expected=326.890000
# predicted=331.765633, expected=332.130000
# predicted=331.281577, expected=338.200000
# predicted=335.951547, expected=367.570000
# predicted=371.499011, expected=423.350000
# predicted=428.189464, expected=451.920000
# predicted=441.584650, expected=448.230000
# predicted=435.262020, expected=439.050000
# predicted=436.864669, expected=531.830000
# predicted=560.476684, expected=587.220000
# predicted=580.108532, expected=625.320000
# predicted=614.504157, expected=620.450000
# predicted=610.877394, expected=630.700000
# predicted=639.221330, expected=602.650000
# predicted=598.393443, expected=616.300000
# Test 5.68819862455
# ...

# %%
plt.plot(test,label="Expected Value")
plt.plot(predictions,dashes=[5,5,5,5],label="Predicted Value")
plt.ylabel("Price in USD")
plt.legend(loc='best')
plt.show(block='False')
